# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('financial_sample.csv')
df
# Out:
#               Segment                   Country     Product   Discount Band   \
# 0          Government                    Canada   Carretera            None
# 1          Government                   Germany   Carretera            None
# 2           Midmarket                    France   Carretera            None
# 3           Midmarket                   Germany   Carretera            None
# 4           Midmarket                    Mexico   Carretera            None
# ..                ...                       ...          ...             ...
# 695    Small Business                    France    Amarilla            High
# 696    Small Business                    Mexico    Amarilla            High
# 697        Government                    Mexico     Montana            High
# 698        Government                    Canada       Paseo            High
# 699  Channel Partners  United States of America         VTT            High
#
# ...

# %%
df.columns = df.columns.str.strip()

# %%
df['Units Sold'] = pd.to_numeric(df['Units Sold'].replace({'\$': '', ',': ''}, regex=True), errors='coerce')
df['Sales'] = pd.to_numeric(df['Sales'].replace({'\$': '', ',': ''}, regex=True), errors='coerce')
df['Profit'] = pd.to_numeric(df['Profit'].replace({'\$': '', ',': ''}, regex=True), errors='coerce')
df['Date'] = pd.to_datetime(df['Date'], errors='coerce')

# %%
summary_stats = df[['Units Sold', 'Sales', 'Profit']].describe()

# %%
summary_stats
# Out:
#         Units Sold         Sales         Profit
# count   700.000000  7.000000e+02     637.000000
# mean   1608.294286  1.696091e+05   27741.010204
# std     867.427859  2.367263e+05   43059.332936
# min     200.000000  1.655080e+03     285.600000
# 25%     905.000000  1.592800e+04    3875.850000
# 50%    1542.500000  3.554020e+04   11106.100000
# 75%    2229.125000  2.610775e+05   25162.000000
# max    4492.500000  1.159200e+06  262200.000000

# %%
sales_by_segment_country = df.groupby(['Segment', 'Country'])[['Sales', 'Profit']].sum().sort_values(by='Sales', ascending=False)

# %%
# Grouping by Segment and Country to observe sales and profit distributions
sales_by_segment_country
# Out:
#                                                  Sales      Profit
# Segment          Country
# Government       France                    12127782.72  2709915.22
# Small Business   United States of America  11456559.00  1072059.00
# Government       Germany                   11452895.94  2677175.94
#                  Canada                    10741236.52  2258471.52
#                  Mexico                     9791599.38  2039159.38
# Small Business   Canada                     9177549.00   900799.00
# Government       United States of America   8390746.11  1703451.10
# Small Business   France                     7369606.50   730731.50
#                  Germany                    7327848.00   771973.00
#                  Mexico                     7096356.00   667606.00
# Enterprise       United States of America   4350605.00    25767.50
#                  Germany                    4086826.25    39022.50
#                  Canada                     3967491.25    42980.00
# ...

# %%
# Correlation analysis between financial variables
correlation_matrix = df[['Units Sold', 'Sales', 'Profit']].corr()

# %%
correlation_matrix
# Out:
#             Units Sold     Sales    Profit
# Units Sold    1.000000  0.326914  0.279973
# Sales         0.326914  1.000000  0.861732
# Profit        0.279973  0.861732  1.000000

# %%
sales_trends = df.groupby(['Year', 'Month Name'])[['Sales']].sum()

# %%
 #Time-series analysis to check sales trends over the years
sales_trends
# Out:
#                         Sales
# Year Month Name
# 2013  December     5368441.08
#       November     7267203.30
#       October      9295611.10
#       September    4484000.03
# 2014  April        6964775.07
#       August       5864622.42
#       December    11998787.90
#       February     7297531.39
#       January      6607761.69
#       July         8102920.18
#       June         9518893.82
#       March        5586859.87
#       May          6210211.06
#       November     5384214.20
#       October     12375819.92
#       September    6398697.24
